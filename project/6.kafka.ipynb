# %%
pip install confluent-kafka

# %%
try:
    from confluent_kafka import Producer
    print("confluent_kafka is installed and imported successfully!")
except ImportError as e:
    print(f"Error importing confluent_kafka: {e}")

# %% [markdown]
# ## Procedure process

# %%
import pandas as pd
from confluent_kafka import Producer
import json

# Function to produce messages to Kafka
def kafka_producer(server, topic, data):
    producer = Producer({'bootstrap.servers': server})
    
    def delivery_report(err, msg):
        if err is not None:
            print('Message delivery failed: {}'.format(err))
        else:
            print('Message delivered to {} [{}]'.format(msg.topic(), msg.partition()))

    for record in data.to_dict(orient='records'):
        producer.produce(topic, value=json.dumps(record), callback=delivery_report)
        producer.poll(0)
    
    producer.flush()

# Kafka configuration
server = '172.21.82.235:9092'  # Remote Kafka server IP and port
topic = 'socialmedia'  # Replace with your topic name

# Sample data to send to Kafka
data = pd.DataFrame({
    'id': [1, 2, 3],
    'name': ['John', 'Jane', 'Doe'],
    'age': [28, 34, 29]
})

# Produce data to Kafka
kafka_producer(server, topic, data)
# Out:
# Message delivered to socialmedia [0]
# Message delivered to socialmedia [0]
# Message delivered to socialmedia [0]

# %% [markdown]
# ## Consumer Process

# %%
from confluent_kafka import Consumer, KafkaError
import json

# Function to consume messages from Kafka
def kafka_consumer(server, group_id, topics):
    consumer = Consumer({
        'bootstrap.servers': server,
        'group.id': group_id,
        'auto.offset.reset': 'earliest'
    })
    
    consumer.subscribe(topics)
    
    while True:
        msg = consumer.poll(1.0)  # Timeout in seconds
        
        if msg is None:
            continue
        
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(msg.error())
                break
        
        try:
            # Deserialize the JSON data
            record = json.loads(msg.value().decode('utf-8'))
            # Process the record (e.g., print it or store it)
            print(record)
        except json.JSONDecodeError as e:
            # Handle the JSON decode error
            print(f"JSONDecodeError: {e}")
            print(f"Message content: {msg.value().decode('utf-8')}")
        
    consumer.close()

# Kafka configuration
server = '172.21.82.235:9092'  # Remote Kafka server IP and port
group_id = 'my_consumer_group'  # Replace with your desired group ID
topics = ['socialmedia']  # Replace with your topic name

# Consume data from Kafka
kafka_consumer(server, group_id, topics)
# Out:
# {'id': 1, 'name': 'John', 'age': 28}
# {'id': 2, 'name': 'Jane', 'age': 34}
# {'id': 3, 'name': 'Doe', 'age': 29}

# %%
pip install confluent-kafka pandas

# %%
Producer read CSV (socialmedia)

# %%
import pandas as pd
from confluent_kafka import Producer
import json

# Function to read CSV data
def read_csv(file_path):
    return pd.read_csv(file_path)

# Function to produce messages to Kafka
def kafka_producer(server, topic, data):
    producer = Producer({'bootstrap.servers': server})
    
    def delivery_report(err, msg):
        if err is not None:
            print(f'Message delivery failed: {err}')
        else:
            print(f'Message delivered to {msg.topic()} [{msg.partition()}]')
    
    for _, row in data.iterrows():
        # Convert each row to JSON and produce to Kafka
        json_data = row.to_json()
        producer.produce(topic, value=json_data.encode('utf-8'), callback=delivery_report)
        producer.poll(0)
    
    producer.flush()

# Kafka configuration
server = '172.21.82.235:9092'  # Replace with your Kafka server address
topic = 'socialmedia1'  # Replace with your desired topic name

# Path to your CSV file
csv_file = './Processed.csv'

# Read CSV file
data = read_csv(csv_file)

# Print the data read from CSV (optional)
print(f"Read data from CSV:\n{data}")

# Produce data to Kafka
kafka_producer(server, topic, data)
# Out:
# Read data from CSV:
#     User_ID   Age      Gender  Platform  Daily_Usage_Time (minutes)  \
# 0     500.0  27.0      Female  Snapchat                       120.0
# 1     488.0  21.0  Non-binary  Snapchat                        60.0
# 2     776.0  28.0  Non-binary  Snapchat                       115.0
# 3     869.0  27.0        Male  Telegram                       105.0
# 4     573.0  21.0  Non-binary  Facebook                        55.0
# ..      ...   ...         ...       ...                         ...
# 91    418.0  27.0        Male   Twitter                        90.0
# 92    184.0  22.0        Male   Twitter                        70.0
# 93    896.0  33.0        Male  LinkedIn                        85.0
# 94    708.0  24.0  Non-binary  Facebook                       110.0
# 95    993.0  24.0        Male  Telegram                        75.0
#
#     Posts_Per_Day  Likes_Received_Per_Day  Comments_Received_Per_Day  \
# 0             4.0                    40.0                       18.0
# 1             1.0                    18.0                        7.0
# 2             3.0                    38.0                       18.0
# 3             3.0                    48.0                       20.0
# 4             3.0                    17.0                        7.0
# ..            ...                     ...                        ...
# 91            3.0                    40.0                       16.0
# 92            1.0                    20.0                        5.0
# 93            4.0                    35.0                       18.0
# 94            6.0                    35.0                       23.0
# 95            3.0                    37.0                       16.0
#
#     Messages_Sent_Per_Day Dominant_Emotion
# 0                    22.0          Neutral
# 1                    12.0          Neutral
# 2                    27.0          Anxiety
# 3                    28.0          Anxiety
# 4                    12.0          Neutral
# ..                    ...              ...
# 91                   24.0          Sadness
# 92                   22.0          Neutral
# 93                   18.0          Boredom
# 94                   25.0          Sadness
# 95                   22.0          Neutral
#
# [96 rows x 10 columns]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]
# Message delivered to socialmedia1 [0]

# %% [markdown]
# ## Consumer read from csv

# %%
from confluent_kafka import Consumer, KafkaError
import json

# Function to consume messages from Kafka
def kafka_consumer(server, group_id, topics):
    consumer = Consumer({
        'bootstrap.servers': server,
        'group.id': group_id,
        'auto.offset.reset': 'earliest'
    })
    
    consumer.subscribe(topics)
    
    while True:
        msg = consumer.poll(1.0)  # Timeout in seconds
        
        if msg is None:
            continue
        
        if msg.error():
            if msg.error().code() == KafkaError._PARTITION_EOF:
                continue
            else:
                print(f"Consumer error: {msg.error()}")
                break
        
        # Deserialize the JSON data
        try:
            record = json.loads(msg.value().decode('utf-8'))
            print(f"Consumed message: {record}")
        except json.JSONDecodeError as e:
            print(f"Error decoding message: {e}")
        
    consumer.close()

# Kafka configuration
server = '172.21.82.235:9092'  # Replace with your Kafka server address
group_id = 'my_consumer_group'  # Replace with your desired group ID
topics = ['socialmedia1']  # Replace with your desired topic name

# Consume data from Kafka
kafka_consumer(server, group_id, topics)
# Out:
# Consumed message: {'User_ID': 500.0, 'Age': 27.0, 'Gender': 'Female', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 120.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 40.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 488.0, 'Age': 21.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 18.0, 'Comments_Received_Per_Day': 7.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 776.0, 'Age': 28.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 115.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 38.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 27.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 869.0, 'Age': 27.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 105.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 48.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 28.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 573.0, 'Age': 21.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 17.0, 'Comments_Received_Per_Day': 7.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 428.0, 'Age': 25.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 160.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 85.0, 'Comments_Received_Per_Day': 26.0, 'Messages_Sent_Per_Day': 30.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 528.0, 'Age': 25.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 160.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 85.0, 'Comments_Received_Per_Day': 26.0, 'Messages_Sent_Per_Day': 30.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 773.0, 'Age': 21.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 17.0, 'Comments_Received_Per_Day': 7.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 382.0, 'Age': 24.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 85.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 33.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 505.0, 'Age': 33.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 45.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 10.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 20.0, 'Age': 32.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 140.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 70.0, 'Comments_Received_Per_Day': 22.0, 'Messages_Sent_Per_Day': 33.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 444.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 105.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 25.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 720.0, 'Age': 32.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 140.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 75.0, 'Comments_Received_Per_Day': 28.0, 'Messages_Sent_Per_Day': 30.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 328.0, 'Age': 25.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 160.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 85.0, 'Comments_Received_Per_Day': 26.0, 'Messages_Sent_Per_Day': 30.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 372.0, 'Age': 35.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 13.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 555.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 15.0, 'Comments_Received_Per_Day': 7.0, 'Messages_Sent_Per_Day': 17.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 181.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 20.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 413.0, 'Age': 34.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 65.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 14.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 15.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 132.0, 'Age': 28.0, 'Gender': 'Male', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 145.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 75.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 35.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 743.0, 'Age': 29.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 95.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 50.0, 'Comments_Received_Per_Day': 22.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 526.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 80.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 20.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 962.0, 'Age': 23.0, 'Gender': 'Male', 'Platform': 'Whatsapp', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 22.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 497.0, 'Age': 22.0, 'Gender': 'Female', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 14.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 275.0, 'Age': 25.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 80.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 13.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 836.0, 'Age': 24.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 11.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 11.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 35.0, 'Age': 29.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 65.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 22.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 760.0, 'Age': 27.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 15.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 700.0, 'Age': 27.0, 'Gender': 'Female', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 120.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 40.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 58.0, 'Age': 29.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 15.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 481.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 20.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 847.0, 'Age': 21.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 90.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 37.0, 'Comments_Received_Per_Day': 14.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 850.0, 'Age': 28.0, 'Gender': 'Female', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 487.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 85.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 45.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 28.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 820.0, 'Age': 32.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 140.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 75.0, 'Comments_Received_Per_Day': 28.0, 'Messages_Sent_Per_Day': 30.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 932.0, 'Age': 28.0, 'Gender': 'Male', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 145.0, 'Posts_Per_Day': 7.0, 'Likes_Received_Per_Day': 80.0, 'Comments_Received_Per_Day': 30.0, 'Messages_Sent_Per_Day': 35.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 599.0, 'Age': 28.0, 'Gender': 'Non-binary', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 18.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 627.0, 'Age': 27.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 11.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 212.0, 'Age': 26.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 95.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 14.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 872.0, 'Age': 35.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 13.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 155.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 15.0, 'Comments_Received_Per_Day': 7.0, 'Messages_Sent_Per_Day': 17.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 830.0, 'Age': 26.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 45.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 8.0, 'Comments_Received_Per_Day': 4.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 174.0, 'Age': 29.0, 'Gender': 'Female', 'Platform': 'Whatsapp', 'Daily_Usage_Time (minutes)': 90.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 24.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 119.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 490.0, 'Age': 30.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 594.0, 'Age': 29.0, 'Gender': 'Female', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 95.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 23.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 28.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 713.0, 'Age': 34.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 65.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 14.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 15.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 801.0, 'Age': 25.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 120.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 50.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 319.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 783.0, 'Age': 34.0, 'Gender': 'Female', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 120.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 60.0, 'Comments_Received_Per_Day': 25.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 376.0, 'Age': 28.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 115.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 38.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 27.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 562.0, 'Age': 23.0, 'Gender': 'Male', 'Platform': 'Whatsapp', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 22.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 693.0, 'Age': 24.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 37.0, 'Comments_Received_Per_Day': 16.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 76.0, 'Age': 28.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 90.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 48.0, 'Comments_Received_Per_Day': 22.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 169.0, 'Age': 27.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 105.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 45.0, 'Comments_Received_Per_Day': 15.0, 'Messages_Sent_Per_Day': 28.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 900.0, 'Age': 27.0, 'Gender': 'Female', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 120.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 40.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 986.0, 'Age': 28.0, 'Gender': 'Female', 'Platform': 'Whatsapp', 'Daily_Usage_Time (minutes)': 100.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 37.0, 'Comments_Received_Per_Day': 14.0, 'Messages_Sent_Per_Day': 26.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 807.0, 'Age': 27.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 85.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 40.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 275.0, 'Age': 25.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 80.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 28.0, 'Comments_Received_Per_Day': 11.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 815.0, 'Age': 28.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 100.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 50.0, 'Comments_Received_Per_Day': 30.0, 'Messages_Sent_Per_Day': 29.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 227.0, 'Age': 27.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 55.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 9.0, 'Comments_Received_Per_Day': 2.0, 'Messages_Sent_Per_Day': 11.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 60.0, 'Age': 27.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 10.0, 'Comments_Received_Per_Day': 4.0, 'Messages_Sent_Per_Day': 15.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 866.0, 'Age': 29.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 4.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 944.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 105.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 25.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 711.0, 'Age': 23.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 45.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 211.0, 'Age': 23.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 45.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 33.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 27.0, 'Comments_Received_Per_Day': 11.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 348.0, 'Age': 26.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 672.0, 'Age': 35.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 13.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 223.0, 'Age': 29.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 15.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 926.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 80.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 20.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 81.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 18.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 997.0, 'Age': 22.0, 'Gender': 'Female', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 14.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 561.0, 'Age': 31.0, 'Gender': 'Male', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 175.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 72.0, 'Comments_Received_Per_Day': 30.0, 'Messages_Sent_Per_Day': 33.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 48.0, 'Age': 26.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 28.0, 'Comments_Received_Per_Day': 11.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 849.0, 'Age': 32.0, 'Gender': 'Male', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 130.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 80.0, 'Comments_Received_Per_Day': 28.0, 'Messages_Sent_Per_Day': 31.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 621.0, 'Age': 26.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 14.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 261.0, 'Age': 29.0, 'Gender': 'Female', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 90.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 22.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 21.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 16.0, 'Age': 21.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 40.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 5.0, 'Comments_Received_Per_Day': 2.0, 'Messages_Sent_Per_Day': 10.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 170.0, 'Age': 22.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 21.0, 'Comments_Received_Per_Day': 8.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 653.0, 'Age': 29.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 85.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 27.0, 'Comments_Received_Per_Day': 9.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 422.0, 'Age': 24.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 105.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 35.0, 'Comments_Received_Per_Day': 20.0, 'Messages_Sent_Per_Day': 23.0, 'Dominant_Emotion': 'Anger'}
# Consumed message: {'User_ID': 378.0, 'Age': 26.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 23.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 149.0, 'Age': 32.0, 'Gender': 'Male', 'Platform': 'Instagram', 'Daily_Usage_Time (minutes)': 130.0, 'Posts_Per_Day': 5.0, 'Likes_Received_Per_Day': 70.0, 'Comments_Received_Per_Day': 19.0, 'Messages_Sent_Per_Day': 31.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 290.0, 'Age': 30.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 28.0, 'Comments_Received_Per_Day': 10.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 759.0, 'Age': 28.0, 'Gender': 'Female', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 95.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 48.0, 'Comments_Received_Per_Day': 22.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Happiness'}
# Consumed message: {'User_ID': 205.0, 'Age': 33.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 45.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 10.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 719.0, 'Age': 23.0, 'Gender': 'Non-binary', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 50.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 6.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 666.0, 'Age': 29.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 60.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 12.0, 'Comments_Received_Per_Day': 4.0, 'Messages_Sent_Per_Day': 12.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 476.0, 'Age': 28.0, 'Gender': 'Non-binary', 'Platform': 'Snapchat', 'Daily_Usage_Time (minutes)': 115.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 38.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 26.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 278.0, 'Age': 26.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 23.0, 'Comments_Received_Per_Day': 12.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 821.0, 'Age': 26.0, 'Gender': 'Male', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 2.0, 'Likes_Received_Per_Day': 30.0, 'Comments_Received_Per_Day': 14.0, 'Messages_Sent_Per_Day': 20.0, 'Dominant_Emotion': 'Anxiety'}
# Consumed message: {'User_ID': 418.0, 'Age': 27.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 90.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 40.0, 'Comments_Received_Per_Day': 16.0, 'Messages_Sent_Per_Day': 24.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 184.0, 'Age': 22.0, 'Gender': 'Male', 'Platform': 'Twitter', 'Daily_Usage_Time (minutes)': 70.0, 'Posts_Per_Day': 1.0, 'Likes_Received_Per_Day': 20.0, 'Comments_Received_Per_Day': 5.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
# Consumed message: {'User_ID': 896.0, 'Age': 33.0, 'Gender': 'Male', 'Platform': 'LinkedIn', 'Daily_Usage_Time (minutes)': 85.0, 'Posts_Per_Day': 4.0, 'Likes_Received_Per_Day': 35.0, 'Comments_Received_Per_Day': 18.0, 'Messages_Sent_Per_Day': 18.0, 'Dominant_Emotion': 'Boredom'}
# Consumed message: {'User_ID': 708.0, 'Age': 24.0, 'Gender': 'Non-binary', 'Platform': 'Facebook', 'Daily_Usage_Time (minutes)': 110.0, 'Posts_Per_Day': 6.0, 'Likes_Received_Per_Day': 35.0, 'Comments_Received_Per_Day': 23.0, 'Messages_Sent_Per_Day': 25.0, 'Dominant_Emotion': 'Sadness'}
# Consumed message: {'User_ID': 993.0, 'Age': 24.0, 'Gender': 'Male', 'Platform': 'Telegram', 'Daily_Usage_Time (minutes)': 75.0, 'Posts_Per_Day': 3.0, 'Likes_Received_Per_Day': 37.0, 'Comments_Received_Per_Day': 16.0, 'Messages_Sent_Per_Day': 22.0, 'Dominant_Emotion': 'Neutral'}
